# %%
import sys
import pandas as pd

print(f"Python Version: {sys.version}")
print(f"Pandas version: {pd.__version__}")
# Out:
# Python Version: 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]
# Pandas version: 2.3.0

# %%
import pandas as pd

filepath = r'C:\Data Analyst\Power BI By Hannan\For Ministry of Industries Job\LSM_Data.xlsx'

factsdf = pd.read_excel(filepath, sheet_name='Facts_Production')
dimitemsdf = pd.read_excel(filepath, sheet_name='Dim_Items')
dimcalendardf = pd.read_excel(filepath, sheet_name='Dim_Calendar')


# Check structure and data types
print(factsdf.info())
print(dimitemsdf.info())
print(dimcalendardf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No           66 non-null     int64
#  1   PSIC_Code    66 non-null     int64
#  2   Item_Name    66 non-null     object
#  3   Fiscal_Year  66 non-null     object
#  4   Period       66 non-null     object
#  5   Value        66 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   No          33 non-null     int64
#  1   PSIC_Code   33 non-null     int64
#  2   Item_Name   33 non-null     object
#  3   UOM         33 non-null     object
#  4   Weightage   33 non-null     float64
#  5   Source      33 non-null     object
#  6   Category    33 non-null     object
# ...

# %%
import pandas as pd

filepath = r'C:\Data Analyst\Power BI By Hannan\For Ministry of Industries Job\LSM_Data.xlsx'

factsdf = pd.read_excel(filepath, sheet_name='Facts_Production')
dimitesmsdf = pd.read_excel(filepath, sheet_name='Dim_Items')
dimcalendardf = pd.read_excel(filepath, sheet_name='Dim_Calendar')


print("Description of the column Value in Facts_Production is as follows: ")
print(factsdf["Value"].describe())
print()
print(factsdf["Value"].value_counts())
print()
print(factsdf.isnull().sum())
print()
print(factsdf.isna().sum())
print()
print(factsdf.isna().mean()*100)
print()
print(factsdf.duplicated().sum())
print()
print("No of unique items in PSIC_Code Column of the Tab Facts_Production are: ", factsdf["PSIC_Code"].nunique())
print("No of unique items in Item_Name Column of the Tab Facts_Production are: ", factsdf["Item_Name"].nunique())
print("No of unique items in Fiscal_Year Column of the Tab Facts_Production are: ", factsdf["Fiscal_Year"].nunique())
print("No of unique items in Period Column of the Tab Facts_Production are: ", factsdf["Period"].nunique())
print("No of unique items in Value Column of the Tab Facts_Production are: ", factsdf["Value"].nunique())
# Out:
# Description of the column Value in Facts_Production is as follows:
# count    6.600000e+01
# mean     3.595479e+05
# std      6.579479e+05
# min      0.000000e+00
# 25%      5.393000e+03
# 50%      3.720700e+04
# 75%      3.423055e+05
# max      2.887955e+06
# Name: Value, dtype: float64
#
# Value
# 0          12
# 1425100     2
# 1455000     2
# 1441900     2
# 1620000     2
# 191366      1
# 39893       1
# 52512       1
# 67984       1
# 203767      1
# 237345      1
# 169117      1
# 2870441     1
# 357577      1
# 363054      1
# 40566       1
# 367574      1
# 15928       1
# 5361        1
# 17845       1
# 62755       1
# 24309       1
# 11992       1
# 3580        1
# 428         1
# 9915        1
# 20370       1
# 639625      1
# 200545      1
# 33500       1
# 29597       1
# 46790       1
# 76325       1
# 182003      1
# 329689      1
# 196964      1
# 2887955     1
# 343536      1
# 338614      1
# 375518      1
# 15398       1
# 27409       1
# 5489        1
# ...

# %%
# print('Hannan: ',dimitesmsdf["PSIC_Code"].value_counts())



print("Description of the column Weightage in Dim_Items is as follows: ")
print(dimitemsdf["Weightage"].describe())
print()
print(dimitemsdf["Weightage"].value_counts())
print()
print(dimitemsdf.isnull().sum())
print()
print(dimitemsdf.isna().sum())
print()
print(dimitemsdf.isna().mean()*100)
print()
print(dimitemsdf.duplicated().sum())
print()
print("No of unique items in PSIC_Code Column of the Tab Dim_Items are: ", dimitemsdf["PSIC_Code"].nunique())
print("No of unique items in Item_Name Column of the Tab Dim_Items are: ", dimitemsdf["Item_Name"].nunique())
print("No of unique items in UOM Column of the Tab Dim_Items are: ", dimitemsdf["UOM"].nunique())
print("No of unique items in the Weightage Column of the Tab Dim_Items are: ", dimitemsdf["Weightage"].nunique())
print("No of unique items in the Source Column of the Tab Dim_Items are: ", dimitemsdf["Source"].nunique())
print("No of unique items in the Category Column of the Tab Dim_Items are: ", dimitemsdf["Category"].nunique())
# Out:
# Description of the column Weightage in Dim_Items is as follows:
# count    29.000000
# mean      0.797483
# std       1.094647
# min       0.000100
# 25%       0.125200
# 50%       0.406500
# 75%       0.923900
# max       4.650000
# Name: Weightage, dtype: float64
#
# Weightage
# 0.4065    4
# 0.1252    4
# 1.1430    3
# 0.9049    2
# 3.4270    1
# 0.9239    1
# 0.3399    1
# 0.1484    1
# 0.1925    1
# 0.0432    1
# 2.5215    1
# 0.0010    1
# 0.0001    1
# 2.0722    1
# 4.6500    1
# 0.3602    1
# 0.2304    1
# 0.0776    1
# 0.0894    1
# 0.6841    1
# Name: count, dtype: int64
#
# No            0
# PSIC_Code     0
# Item_Name     0
# UOM           0
# Weightage     4
# Source        0
# Category      0
# Unnamed: 7    0
# dtype: int64
#
# No            0
# PSIC_Code     0
# Item_Name     0
# UOM           0
# Weightage     4
# Source        0
# Category      0
# Unnamed: 7    0
# dtype: int64
#
# No             0.000000
# PSIC_Code      0.000000
# Item_Name      0.000000
# ...

# %%
print(dimcalendardf.isnull().sum())
print()
print(dimcalendardf.isna().sum())
print()
print(dimcalendardf.isna().mean()*100)
print()
print(dimcalendardf.duplicated().sum())

print()
print(dimcalendardf["Sort_Order"].value_counts())
print()
# Out:
# Fiscal_Year    0
# Sort_Order     0
# dtype: int64
#
# Fiscal_Year    0
# Sort_Order     0
# dtype: int64
#
# Fiscal_Year    0.0
# Sort_Order     0.0
# dtype: float64
#
# 0
#
# Sort_Order
# 1    1
# 2    1
# Name: count, dtype: int64

# %%
# Check for nulls in each table
print(final_df.isnull().sum())

# Check for zero production entries which might be data gaps
zero_production = final_df[final_df['Value'] == 0]
print(f"Records with zero production: {len(zero_production)}")
# Out:
# No_x            0
# PSIC_Code       1
# Item_Name_x     0
# Fiscal_Year     0
# Period          0
# Value          34
# No_y            1
# Item_Name_y     1
# UOM             1
# Weightage      33
# Source          1
# Category        1
# Unnamed: 7      1
# Sort_Order      0
# dtype: int64
# Records with zero production: 0
